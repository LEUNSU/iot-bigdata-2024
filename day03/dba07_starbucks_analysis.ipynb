# %% [markdown]
# ### 스타벅스 매장 입지 분석
# - 순서(아래 체크박스는 주피터노트북 마크다운에서는 안 됨)
#     - [x] ~~데이터 수집~~
#     - [ ] 데이터 전처리(다시)
#     - [ ] 분석
#     - [ ] 시각화

# %%
# 분석, 시각화 라이브러리 사용
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams, rc, font_manager
import warnings
import seaborn as sns
import time
from tqdm import tqdm  # 반복 진행 프로그레스바 모듈
import folium
from folium.features import DivIcon  # html로 텍스트 표시할 아이콘 모듈
import json

# %%
# 맷플롯립 한글 및 기타설정
## 맑은 고딕
font_path = 'C:/Windows/Fonts/malgun.ttf'
font_name = font_manager.FontProperties(fname=font_path).get_name() # Malgun Gothic
warnings.simplefilter('ignore') # 경고메시지 출력숨김

## 맷플롯립 설정
plt.rcParams['font.family'] = font_name # 폰트 설정
plt.rcParams['font.size'] = 12 # 글자크기
plt.rcParams['figure.figsize'] = (12, 6) # (W, H)
plt.rcParams['axes.grid'] = True # 차트 가로세로줄 표시
plt.rcParams['axes.unicode_minus'] = False # 한글설정 후 마이너스깨짐 방지

## 시본 설정
sns.set_theme(font=font_name, style='darkgrid', rc={'axes.unicode_minus':False})

# %% [markdown]
# #### 데이터 전처리
# - 데이터 로드 후, 확인, 결측치나 이상치를 제거

# %%
## 스타벅스 서울매장정보
df_seoul_startbuck = pd.read_csv('./data/스타벅스_서울매장정보_최종.csv', index_col=)
df_seoul_startbuck.tail()
# Out:
#      매장코드   매장명     매장종류                                     주소         위도  \
# 609   838  사가정역  general                      서울특별시 중랑구 면목로 310  37.579594
# 610   493   상봉역  general                서울특별시 중랑구 망우로 307 (상봉동)  37.596890
# 611  1668    묵동  general  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  37.615368
# 612  2002   양원역  general              서울특별시 중랑구 양원역로10길 3 (망우동)  37.606654
# 613  1749   중화역  general                   서울특별시 중랑구 봉화산로 35 1층  37.601709
#
#              경도
# 609  127.087966
# 610  127.086470
# 611  127.076633
# 612  127.106360
# 613  127.078411

# %%
## 서울구별 위치 정보
df_seoul_municipality = pd.read_csv('./data/서울구별위치.csv', index_col=0)
df_seoul_municipality.tail()
# Out:
#    docity  do city   longitude   latitude
# 20  서울용산구  서울  용산구  126.967522  37.536094
# 21  서울은평구  서울  은평구  126.931242  37.599969
# 22  서울종로구  서울  종로구  126.981642  37.570378
# 23   서울중구  서울   중구  126.999642  37.561003
# 24  서울중랑구  서울  중랑구  127.094778  37.603806

# %% [markdown]
# - 데이터 확인

# %%
## 결측치 확인(값이 빠져있는 것)
df_seoul_startbuck.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 614 entries, 0 to 613
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   매장코드    614 non-null    int64
#  1   매장명     614 non-null    object
#  2   매장종류    614 non-null    object
#  3   주소      614 non-null    object
#  4   위도      614 non-null    float64
#  5   경도      614 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 33.6+ KB

# %%
df_seoul_municipality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 0 to 24
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   docity     25 non-null     object
#  1   do         25 non-null     object
#  2   city       25 non-null     object
#  3   longitude  25 non-null     float64
#  4   latitude   25 non-null     float64
# dtypes: float64(2), object(3)
# memory usage: 1.2+ KB

# %% [markdown]
# #### 서울 행정구역 경계지도 Geojson(Geometry json 파일) 지도표시
# - https://github.com/southkorea/seoul-maps
#
# - 윈도우 Powershell로 다운로드
#     - 터미널 새터미널로 오픈
#     - day3/data로 이동 다음
#     - wget - Uri https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json
# - 깃허브에서 다운로드

# %% [markdown]
# #### 데이터 전처리 계속

# %%
## 스타벅스 서울매장정보확인
df_seoul_startbuck.head()
# Out:
#    매장코드      매장명     매장종류                          주소         위도          경도
# 0  1509  역삼아레나빌딩  general     서울특별시 강남구 언주로 425 (역삼동)  37.501087  127.043069
# 1  1434   논현역사거리  general    서울특별시 강남구 강남대로 538 (논현동)  37.510178  127.022223
# 2  1595  신사역성일빌딩  general    서울특별시 강남구 강남대로 584 (논현동)  37.513931  127.020606
# 3  1527   국기원사거리  general    서울특별시 강남구 테헤란로 125 (역삼동)  37.499517  127.031495
# 4  1468   대치재경빌딩  general  서울특별시 강남구 남부순환로 2947 (대치동)  37.494668  127.062583

# %%
## 주소에서 '강남구' 따로 분리해서 새로운 컬럼을 생성
guList = []

for address in tqdm(df_seoul_startbuck['주소']):
    tmp_addr = address.split(' ')
    #print(tmp_addr[1]) # tmp_addr[1] 구명
    guList.append(tmp_addr[1])
# Out:
# 100%|██████████| 614/614 [00:00<00:00, 616396.04it/s]

# %%
len(guList)
# Out:
# 614

# %%
## guList를 df_seoul_starbuck에 마지막 컬럼으로 추가
df_seoul_startbuck['구'] = guList

# %%
df_seoul_startbuck.tail()
# Out:
#      매장코드   매장명     매장종류                                     주소         위도  \
# 609   838  사가정역  general                      서울특별시 중랑구 면목로 310  37.579594
# 610   493   상봉역  general                서울특별시 중랑구 망우로 307 (상봉동)  37.596890
# 611  1668    묵동  general  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  37.615368
# 612  2002   양원역  general              서울특별시 중랑구 양원역로10길 3 (망우동)  37.606654
# 613  1749   중화역  general                   서울특별시 중랑구 봉화산로 35 1층  37.601709
#
#              경도    구
# 609  127.087966  중랑구
# 610  127.086470  중랑구
# 611  127.076633  중랑구
# 612  127.106360  중랑구
# 613  127.078411  중랑구

# %%
## docity컬럼 삭제, do=>시, city=>구, longi..=>경도, lati..=>위도
df_seoul_municipality = df_seoul_municipality[['do', 'city', 'latitude', 'longitude']]
df_seoul_municipality.tail()
# Out:
#     do city   latitude   longitude
# 20  서울  용산구  37.536094  126.967522
# 21  서울  은평구  37.599969  126.931242
# 22  서울  종로구  37.570378  126.981642
# 23  서울   중구  37.561003  126.999642
# 24  서울  중랑구  37.603806  127.094778

# %%
## 이름 변경
df_seoul_municipality.columns = ['시', '구', '위도', '경도']

# %%
df_seoul_municipality.tail()
# Out:
#      시    구         위도          경도
# 20  서울  용산구  37.536094  126.967522
# 21  서울  은평구  37.599969  126.931242
# 22  서울  종로구  37.570378  126.981642
# 23  서울   중구  37.561003  126.999642
# 24  서울  중랑구  37.603806  127.094778

# %% [markdown]
# ### 판다스 중급 기능
# - 스타벅스 서울매장 정보를 구별로 통계(피벗)

# %%
## 스타벅스 매장에 구로 그룹화, 매장 수로 카운팅
## pivot_table 속성: values->어느 값을 합칠래, index->어느 값이 인덱스가 될래,
## aggfunc->합산을 함수는 뭔데(합, 갯수, 표준편차, 분산....) 

## 아래의 결과는 메모리상의 결과이고, 하나의 변수에 할당해야 함
df_seoul_startbuck.pivot_table(values='매장명', index='구', aggfunc='count').rename(columns={'매장명':'매장수'})
# Out:
#       매장수
# 구
# 강남구    91
# 강동구    17
# 강북구     6
# 강서구    28
# 관악구    12
# 광진구    19
# 구로구    15
# 금천구    13
# 노원구    14
# 도봉구     7
# 동대문구   13
# 동작구    11
# 마포구    37
# 서대문구   21
# 서초구    48
# 성동구    14
# 성북구    16
# 송파구    37
# 양천구    17
# 영등포구   41
# 용산구    24
# 은평구    14
# 종로구    39
# 중구     52
# 중랑구     8

# %%
df_seoul_startbuck_count = df_seoul_startbuck.pivot_table(values='매장명', index='구', aggfunc='count').rename(columns={'매장명':'매장수'})
df_seoul_startbuck_count.tail()
# Out:
#      매장수
# 구
# 용산구   24
# 은평구   14
# 종로구   39
# 중구    52
# 중랑구    8

# %%
df_seoul_startbuck_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 강남구 to 중랑구
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   매장수     25 non-null     int64
# dtypes: int64(1)
# memory usage: 400.0+ bytes

# %%
# 구별 매장정보를 차트화
plt.figure(figsize=(16, 4))
bar = plt.bar(df_seoul_startbuck_count.index, df_seoul_startbuck_count['매장수'], color='green')
# plt.summer()
plt.title('서울 구별 매장수')
plt.xticks(rotation=45)

# 숫자 넣는 부분
for rect in bar:
    # 바 차트 각 값별 높이 == 데이터 크기
    value = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, value, f'{value:d}', ha='center', va='bottom', size = 12) # 바차트 정중앙에 텍스트를 표시

plt.show()

# %% [markdown]
# #### 서울시 인구 및 사업체 정보
# - 서울열린데이터광장(https://data.seoul.go.kr/)에서 다운로드 후 전처리
# - 서울_구별인구정보, 서울_구별사업체정보.xlsx

# %%
## 서울 구별 인구데이터
df_seoul_population = pd.read_excel('./data/서울_구별인구정보.xlsx', header=0)

df_seoul_population.head()
# Out:
#      구     세대소계     성별소계       남자       여자    한국인소계     남자.1     여자.1  \
# 0   소계  4469417  9638799  4649446  4989353  9386034  4540031  4846003
# 1  종로구    72067   150453    71890    78563   139417    67306    72111
# 2   중구    64714   131793    63495    68298   121312    58659    62653
# 3  용산구   107825   227106   109826   117280   213151   102312   110839
# 4  성동구   133089   284766   137620   147146   277361   134519   142842
#
#    등록외국인소계    남자.2    여자.2  세대당인구    65세이상
# 0   252765  109415  143350   2.10  1743696
# 1    11036    4584    6452   1.93    28764
# 2    10481    4836    5645   1.87    25920
# 3    13955    7514    6441   1.98    39747
# 4     7405    3101    4304   2.08    49462

# %%
## 전체 소계만 삭제(drop) - 실행할 때마다 0번 인덱스가 날아갈 수 있기때문에 한번 실행
df_seoul_population.drop(0, inplace=True)

# %%
df_seoul_population.head()
# Out:
#      구    세대소계    성별소계      남자      여자   한국인소계    남자.1    여자.1  등록외국인소계  남자.2  \
# 1  종로구   72067  150453   71890   78563  139417   67306   72111    11036  4584
# 2   중구   64714  131793   63495   68298  121312   58659   62653    10481  4836
# 3  용산구  107825  227106  109826  117280  213151  102312  110839    13955  7514
# 4  성동구  133089  284766  137620  147146  277361  134519  142842     7405  3101
# 5  광진구  170077  351180  167562  183618  335554  161277  174277    15626  6285
#
#    여자.2  세대당인구  65세이상
# 1  6452   1.93  28764
# 2  5645   1.87  25920
# 3  6441   1.98  39747
# 4  4304   2.08  49462
# 5  9341   1.97  56819

# %%
## 서울 구별 사업체 현황로드
df_seoul_business = pd.read_excel('./data/서울_구별사업체정보.xlsx')
df_seoul_business.head()
# Out:
#      구       소계   여성대표자     성별소계       남자       여자
# 0   소계  1188091  407948  5771226  3218529  2552697
# 1  종로구    48361   16563   275063   153210   121853
# 2   중구    70308   25794   386564   213782   172782
# 3  용산구    29680   10454   152605    84314    68291
# 4  성동구    41665   13447   203221   116978    86243

# %%
## 서울 구별 사업체도 소계를 삭제
df_seoul_business.drop(index=0, inplace=True)

# %%
df_seoul_business.head()
# Out:
#      구     소계  여성대표자    성별소계      남자      여자
# 1  종로구  48361  16563  275063  153210  121853
# 2   중구  70308  25794  386564  213782  172782
# 3  용산구  29680  10454  152605   84314   68291
# 4  성동구  41665  13447  203221  116978   86243
# 5  광진구  33706  12297  129707   71124   58583

# %%
df_seoul_business.tail()
# Out:
#       구      소계  여성대표자    성별소계      남자      여자
# 21  관악구   37915  13641  128417   68392   60025
# 22  서초구   71958  23066  487976  290084  197892
# 23  강남구  110007  35453  801419  447809  353610
# 24  송파구   74531  25400  400781  244588  156193
# 25  강동구   41660  15226  157465   83415   74050

# %%
## 서울시 구별 인구 시각화
## df_seoul_population['구'] - x축
## df_seoul_population['성별소계'] - y축
plt.figure(figsize=(16, 4))
x = df_seoul_population['구'].to_list()
y = df_seoul_population['성별소계'].to_list()
plt.plot(x, y, label='성별소계', marker='o') # marker : o, ^, s, *
plt.plot(df_seoul_population['구'], df_seoul_population['남자'], label='남자')
plt.plot(df_seoul_population['구'], df_seoul_population['여자'], label='여자')

plt.xticks(rotation=45)
plt.legend()
plt.title('서울시 구별 인구현황')

# 숫자 넣는 부분, height + 0.25로 숫자 약간 위로 위치하게 조정
for i in range(len(x)):
    value = y[i]
    plt.text(x[i], value + 0.5, f'{value:d}', ha='center', va='bottom', size = 10)

plt.show()

# %%
## 서울시 구별 인구에서 성별소계만 추출
df_seoul_population[['구', '성별소계']]
# Out:
#        구    성별소계
# 1    종로구  150453
# 2     중구  131793
# 3    용산구  227106
# 4    성동구  284766
# 5    광진구  351180
# 6   동대문구  359873
# 7    중랑구  387470
# 8    성북구  438168
# 9    강북구  292977
# 10   도봉구  309494
# 11   노원구  502925
# 12   은평구  470869
# 13  서대문구  320629
# 14   마포구  375162
# 15   양천구  439252
# 16   강서구  568826
# 17   구로구  415651
# 18   금천구  241105
# 19  영등포구  397800
# 20   동작구  389714
# 21   관악구  497883
# 22   서초구  412078
# 23   강남구  550282
# 24   송파구  660025
# 25   강동구  463318

# %%
## 스타벅스 서울 구별 정보 합치기(merge) == DB join
## merge에는 inplace= 속성이 없음. 합친 값을 다른 변수에 할당
df_seoul_muni_and_pop = pd.merge(left=df_seoul_municipality, right=df_seoul_population[['구', '성별소계']], how='left', on='구')

# %%
df_seoul_muni_and_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시       25 non-null     object
#  1   구       25 non-null     object
#  2   위도      25 non-null     float64
#  3   경도      25 non-null     float64
#  4   성별소계    25 non-null     int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.1+ KB

# %%
df_seoul_muni_and_pop.head()
# Out:
#     시    구         위도          경도    성별소계
# 0  서울  강남구  37.514575  127.049556  550282
# 1  서울  강동구  37.527367  127.125864  463318
# 2  서울  강북구  37.636956  127.027719  292977
# 3  서울  강서구  37.548156  126.851675  568826
# 4  서울  관악구  37.475386  126.953844  497883

# %%
## inner 쓰지않고 left 쓰는 이유 : 빈 열을 지우지않기 위해서
df_seoul_muni_and_pop_sbcount = pd.merge(left=df_seoul_muni_and_pop, right=df_seoul_startbuck_count, how='left', on='구')

# %%
df_seoul_muni_and_pop_sbcount.tail()
# Out:
#      시    구         위도          경도    성별소계  매장수
# 20  서울  용산구  37.536094  126.967522  227106   24
# 21  서울  은평구  37.599969  126.931242  470869   14
# 22  서울  종로구  37.570378  126.981642  150453   39
# 23  서울   중구  37.561003  126.999642  131793   52
# 24  서울  중랑구  37.603806  127.094778  387470    8

# %%
df_seoul_business.tail()
# Out:
#       구      소계  여성대표자    성별소계      남자      여자
# 21  관악구   37915  13641  128417   68392   60025
# 22  서초구   71958  23066  487976  290084  197892
# 23  강남구  110007  35453  801419  447809  353610
# 24  송파구   74531  25400  400781  244588  156193
# 25  강동구   41660  15226  157465   83415   74050

# %%
## 총 통계치
df_seoul_total = pd.merge(left=df_seoul_muni_and_pop_sbcount, right=df_seoul_business[['구', '소계', '성별소계']], how='left', on='구')

# %%
df_seoul_total.tail()
# Out:
#      시    구         위도          경도  성별소계_x  매장수     소계  성별소계_y
# 20  서울  용산구  37.536094  126.967522  227106   24  29680  152605
# 21  서울  은평구  37.599969  126.931242  470869   14  36509  109031
# 22  서울  종로구  37.570378  126.981642  150453   39  48361  275063
# 23  서울   중구  37.561003  126.999642  131793   52  70308  386564
# 24  서울  중랑구  37.603806  127.094778  387470    8  39310  113144

# %%
## 컬럼이름 변경
df_seoul_total.columns = ['시', '구', '위도', '경도', '인구수', '매장수', '사업체수', '사업체종사자수']

# %%
df_seoul_total.head()
# Out:
#     시    구         위도          경도     인구수  매장수    사업체수  사업체종사자수
# 0  서울  강남구  37.514575  127.049556  550282   91  110007   801419
# 1  서울  강동구  37.527367  127.125864  463318   17   41660   157465
# 2  서울  강북구  37.636956  127.027719  292977    6   26385    80222
# 3  서울  강서구  37.548156  126.851675  568826   28   58806   290473
# 4  서울  관악구  37.475386  126.953844  497883   12   37915   128417

# %%
df_seoul_total.tail()
# Out:
#      시    구         위도          경도     인구수  매장수   사업체수  사업체종사자수
# 20  서울  용산구  37.536094  126.967522  227106   24  29680   152605
# 21  서울  은평구  37.599969  126.931242  470869   14  36509   109031
# 22  서울  종로구  37.570378  126.981642  150453   39  48361   275063
# 23  서울   중구  37.561003  126.999642  131793   52  70308   386564
# 24  서울  중랑구  37.603806  127.094778  387470    8  39310   113144

# %%
## 최종 DF csv 저장
df_seoul_total.to_csv('./data/서울구별_인구및사업체현황.csv')

# %% [markdown]
# #### 스타벅스 입지 분석, 지도 시각화

# %%
## 스타벅스 서울 매장 정보
df_seoul_startbuck.tail()
# Out:
#      매장코드   매장명     매장종류                                     주소         위도  \
# 609   838  사가정역  general                      서울특별시 중랑구 면목로 310  37.579594
# 610   493   상봉역  general                서울특별시 중랑구 망우로 307 (상봉동)  37.596890
# 611  1668    묵동  general  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  37.615368
# 612  2002   양원역  general              서울특별시 중랑구 양원역로10길 3 (망우동)  37.606654
# 613  1749   중화역  general                   서울특별시 중랑구 봉화산로 35 1층  37.601709
#
#              경도    구
# 609  127.087966  중랑구
# 610  127.086470  중랑구
# 611  127.076633  중랑구
# 612  127.106360  중랑구
# 613  127.078411  중랑구

# %%
## 지도 표시
seoul_center = [37.550800, 126.989857] # ???
seoul_map = folium.Map(location=seoul_center, zoom_start=14)

## 각 매장별 위치, 지도에 마커로 표시, 614개 위치에 마커 표시
for idx in df_seoul_startbuck.index:
    lat = df_seoul_startbuck.loc[idx, '위도'] # 위도 DF.loc[행, 열]
    lng = df_seoul_startbuck.loc[idx, '경도'] # 경도
    # 마커표시
    # folium.CircleMarker(location=[lat, lng], color='green').add_to(seoul_map)
    popup_text = f'{df_seoul_startbuck.loc[idx, "매장명"]}<br/>{df_seoul_startbuck.loc[idx,"주소"]}'
    popup = folium.Popup(popup_text, max_width=500)
    folium.Marker(location=[lat, lng], color='green', popup=popup).add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf2a2126e64b2798a2e77f8ae46f803f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf2a2126e64b2798a2e77f8ae46f803f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf2a2126e64b2798a2e77f8ae46f803f = L.map(
#                 &quot;map_cf2a2126e64b2798a2e77f8ae46f803f&quot;,
#                 {
#                     center: [37.5508, 126.989857],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba2368ae3682a66b70b3496b7b675a38 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ba2368ae3682a66b70b3496b7b675a38.addTo(map_cf2a2126e64b2798a2e77f8ae46f803f);
#
#
#             var marker_305b34c40d630f1a3521971947231225 = L.marker(
#                 [37.501087, 127.043069],
#                 {&quot;color&quot;: &quot;green&quot;}
#             ).addTo(map_cf2a2126e64b2798a2e77f8ae46f803f);
#
#
#         var popup_5bba23aab6e1f13171f0b054a537aef8 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_f3861d3e2c6162bd197bb9be1045b948 = $(`&lt;div id=&quot;html_f3861d3e2c6162bd197bb9be1045b948&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;역삼아레나빌딩&lt;br/&gt;서울특별시 강남구 언주로 425 (역삼동)&lt;/div&gt;`)[0];
#                 popup_5bba23aab6e1f13171f0b054a537aef8.setContent(html_f3861d3e2c6162bd197bb9be1045b948);
#
#
#
#         marker_305b34c40d630f1a3521971947231225.bindPopup(popup_5bba23aab6e1f13171f0b054a537aef8)
#         ;
#
#
#
#
#             var marker_9b930c15e8ba96593c284e08fd2c0a53 = L.marker(
#                 [37.510178, 127.022223],
#                 {&quot;color&quot;: &quot;green&quot;}
#             ).addTo(map_cf2a2126e64b2798a2e77f8ae46f803f);
#
#
#         var popup_4b0fd08be329c6c73a06ec8a851e133c = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_6e61799d20960e71823a950b59d3711f = $(`&lt;div id=&quot;html_6e61799d20960e71823a950b59d3711f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;논현역사거리&lt;br/&gt;서울특별시 강남구 강남대로 538 (논현동)&lt;/div&gt;`)[0];
#                 popup_4b0fd08be329c6c73a06ec8a851e133c.setContent(html_6e61799d20960e71823a950b59d3711f);
#
#
#
#         marker_9b930c15e8ba96593c284e08fd2c0a53.bindPopup(popup_4b0fd08be329c6c73a06ec8a851e133c)
#         ;
#
#
#
#
#             var marker_e70b3345f2c934bf10d5b3b7a904849e = L.marker(
#                 [37.5139309, 127.0206057],
#                 {&quot;color&quot;: &quot;green&quot;}
#             ).addTo(map_cf2a2126e64b2798a2e77f8ae46f803f);
#
#
#         var popup_ceea5c39feb0f7e471732bdf8f691d40 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_53fae377a01e4ff06bb82a83310427a7 = $(`&lt;div id=&quot;html_53fae377a01e4ff06bb82a83310427a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;신사역성일빌딩&lt;br/&gt;서울특별시 강남구 강남대로 584 (논현동)&lt;/div&gt;`)[0];
#                 popup_ceea5c39feb0f7e471732bdf8f691d40.setContent(html_53fae377a01e4ff06bb82a83310427a7);
#
#
#
#         marker_e70b3345f2c934bf10d5b3b7a904849e.bindPopup(popup_ceea5c39feb0f7e471732bdf8f691d40)
#         ;
#
#
#
#
#             var marker_662a24440b05328811e8157bb6a46424 = L.marker(
#                 [37.499517, 127.031495],
#                 {&quot;color&quot;: &quot;green&quot;}
#             ).addTo(map_cf2a2126e64b2798a2e77f8ae46f803f);
#
#
#         var popup_77b5a952f960961c1eb1e8eb337ad194 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_a047cf3b9f80c91a6d4b4703107e931d = $(`&lt;div id=&quot;html_a047cf3b9f80c91a6d4b4703107e931d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;국기원사거리&lt;br/&gt;서울특별시 강남구 테헤란로 125 (역삼동)&lt;/div&gt;`)[0];
#                 popup_77b5a952f960961c1eb1e8eb337ad194.setContent(html_a047cf3b9f80c91a6d4b4703107e931d);
#
#
#
#         marker_662a24440b05328811e8157bb6a46424.bindPopup(popup_77b5a952f960961c1eb1e8eb337ad194)
#         ;
#
#
#
#
#             var marker_b7af6d255d63971a768fb8ebd473a3e9 = L.marker(
#                 [37.494668, 127.062583],
#                 {&quot;color&quot;: &quot;green&quot;}
#             ).addTo(map_cf2a2126e64b2798a2e77f8ae46f803f);
#
#
#         var popup_0ea545aaca5a8b4dfb5f62095c88503f = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_1cef219318e5cf27cd7a22d4584a092e = $(`&lt;div id=&quot;html_1cef219318e5cf27cd7a22d4584a092e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;대치재경빌딩&lt;br/&gt;서울특별시 강남구 남부순환로 2947 (대치동)&lt;/div&gt;`)[0];
#                 popup_0ea545aaca5a8b4dfb5f62095c88503f.setContent(html_1cef219318e5cf27cd7a22d4584a092e);
#
#
#
#         marker_b7af6d255d63971a768fb8ebd473a3e9.bindPopu

# %%
## 매장타입, 갯수를 뽑을 때 pivot처럼 영구적으로 사용할 것이 아니면, value_counts()
df_seoul_startbuck['매장종류'].value_counts()
# Out:
# 매장종류
# general      555
# reserve       34
# generalDT     23
# generalWT      2
# Name: count, dtype: int64

# %%
## 지도 표시
seoul_center = [37.550800, 126.989857] # ???
seoul_map = folium.Map(location=seoul_center, zoom_start=11)

## 각 매장별 위치, 지도에 마커로 표시, 614ro 위치에 마커 표시
for idx in df_seoul_startbuck.index:
    lat = df_seoul_startbuck.loc[idx, '위도'] # 위도 DF.loc[행, 열]
    lng = df_seoul_startbuck.loc[idx, '경도'] # 경도
    # 마커 표시
    #folium.CircleMarker(location=[lat, lng], color='green').add_to(seoul_map)
    popup_text = f'<strong style="font-size:15px;color:blue">{df_seoul_startbuck.loc[idx, "매장명"]}</strong><br/>{df_seoul_startbuck.loc[idx, "주소"]}'
    popup = folium.Popup(popup_text, max_width=500)
    folium.Marker(location=[lat, lng], color='green', popup=popup).add_to(seoul_map)

# %%
## 매장종류별 지도 시각화
seoul_center = [37.550800, 126.989857] 
seoul_map = folium.Map(location=seoul_center, zoom_start=11)

## 각 매장별 위치를 지도 표시
for idx in df_seoul_startbuck.index:
    lat = df_seoul_startbuck.loc[idx, '위도'] 
    lng = df_seoul_startbuck.loc[idx, '경도']
    shop_name = df_seoul_startbuck.loc[idx,'매장명'] 
    shop_type = df_seoul_startbuck.loc[idx,'매장종류'] # general ~ generalWT까지 네가지

    popup_text = f'<strong style="font-size:15px;color:blue">{df_seoul_startbuck.loc[idx, "매장명"]}</strong><br/>{df_seoul_startbuck.loc[idx, "주소"]}'
    popup = folium.Popup(popup_text, max_width=500)

    ## 매장종류별로 서클마커 색상을 변경
    fill_color = ''
    if shop_type.upper() == 'GENERAL': 
        fill_color = 'darlgreen'
        size = 5
    elif shop_type.upper() == 'RESERVE':
        fill_color = 'black'
        size = 8
    elif shop_type.upper() == 'GENERALDT':
        fill_color = 'blue'
        size = 8
    elif shop_type.upper() == 'GENERALWT':
        fill_color = 'yellow'
        size = 7
    

    # 서클마커
    ## popup은 그냥 글자만 입력하면 팝업이 세로로 나옴(보기 싫음)
    folium.CircleMarker(location=[lat, lng], popup=popup, fill=True, fill_color=fill_color, fill_opacity=1,
                        color='darkgreen', weight=1, radius=size).add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ea748368fa91a1ad6d8c115647b5aa0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ea748368fa91a1ad6d8c115647b5aa0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ea748368fa91a1ad6d8c115647b5aa0 = L.map(
#                 &quot;map_9ea748368fa91a1ad6d8c115647b5aa0&quot;,
#                 {
#                     center: [37.5508, 126.989857],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81f4c775f4a1641014b08db7149ac82e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_81f4c775f4a1641014b08db7149ac82e.addTo(map_9ea748368fa91a1ad6d8c115647b5aa0);
#
#
#             var circle_marker_cba6a82979b5bd8cb03bce01378efbfb = L.circleMarker(
#                 [37.501087, 127.043069],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darlgreen&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_9ea748368fa91a1ad6d8c115647b5aa0);
#
#
#         var popup_472c9ffe815e8767fa3071c2ad6411ec = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_25c7fb26fc1e471435cb957306b37b79 = $(`&lt;div id=&quot;html_25c7fb26fc1e471435cb957306b37b79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong style=&quot;font-size:15px;color:blue&quot;&gt;역삼아레나빌딩&lt;/strong&gt;&lt;br/&gt;서울특별시 강남구 언주로 425 (역삼동)&lt;/div&gt;`)[0];
#                 popup_472c9ffe815e8767fa3071c2ad6411ec.setContent(html_25c7fb26fc1e471435cb957306b37b79);
#
#
#
#         circle_marker_cba6a82979b5bd8cb03bce01378efbfb.bindPopup(popup_472c9ffe815e8767fa3071c2ad6411ec)
#         ;
#
#
#
#
#             var circle_marker_9cc3d8f2a88291d14f1c84c0297193ce = L.circleMarker(
#                 [37.510178, 127.022223],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darlgreen&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_9ea748368fa91a1ad6d8c115647b5aa0);
#
#
#         var popup_9444bac7d8e1c22396d14c470b951fe7 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_e27dc07cf7685293a926a55e47cc161b = $(`&lt;div id=&quot;html_e27dc07cf7685293a926a55e47cc161b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong style=&quot;font-size:15px;color:blue&quot;&gt;논현역사거리&lt;/strong&gt;&lt;br/&gt;서울특별시 강남구 강남대로 538 (논현동)&lt;/div&gt;`)[0];
#                 popup_9444bac7d8e1c22396d14c470b951fe7.setContent(html_e27dc07cf7685293a926a55e47cc161b);
#
#
#
#         circle_marker_9cc3d8f2a88291d14f1c84c0297193ce.bindPopup(popup_9444bac7d8e1c22396d14c470b951fe7)
#         ;
#
#
#
#
#             var circle_marker_cb2eae0898a131b44f24d155ffe51e11 = L.circleMarker(
#                 [37.5139309, 127.0206057],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darlgreen&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_9ea748368fa91a1ad6d8c115647b5aa0);
#
#
#         var popup_f3f43c22f384fb0a3796048e84790038 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_de67cddbe56fdd4a9750d9e585be61d7 = $(`&lt;div id=&quot;html_de67cddbe56fdd4a9750d9e585be61d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong style=&quot;font-size:15px;color:blue&quot;&gt;신사역성일빌딩&lt;/strong&gt;&lt;br/&gt;서울특별시 강남구 강남대로 584 (논현동)&lt;/div&gt;`)[0];
#                 popup_f3f43c22f384fb0a3796048e84790038.setContent(html_de67cddbe56fdd4a9750d9e585be61d7);
#
#
#
#         circle_marker_cb2eae0898a131b44f24d155ffe51e11.bindPopup(popup_f3f43c22f384fb0a3796048e84790038)
#         ;
#
#
#
#
#             var circle_marker_be7245e63b6f3046195aa877f3467366 = L.circle

# %% [markdown]
# - 실행결과
#
# <img src= "https://raw.githubusercontent.com/LEUNSU/iot-bigdata-2024/main/images/bda001.png" width="730">

# %% [markdown]
# #### 서울 구별 매장수 지도 시각화

# %%
df_seoul_total.tail()
# Out:
#      시    구         위도          경도     인구수  매장수   사업체수  사업체종사자수
# 20  서울  용산구  37.536094  126.967522  227106   24  29680   152605
# 21  서울  은평구  37.599969  126.931242  470869   14  36509   109031
# 22  서울  종로구  37.570378  126.981642  150453   39  48361   275063
# 23  서울   중구  37.561003  126.999642  131793   52  70308   386564
# 24  서울  중랑구  37.603806  127.094778  387470    8  39310   113144

# %%
# GEOJSON서울 구별 경계값
path = './data/seoul_municipalities_geo_simple.json'
geojson = json.load(open(path, encoding='utf-8'))

# %%
## 이 외 geometry.cordinates 값으로 경계를 그림
geojson['features'][0]['properties']
# Out:
# {'code': '11250',
#  'name': '강동구',
#  'name_eng': 'Gangdong-gu',
#  'base_year': '2013'}

# %%
## 스타일 지정함수
def set_style(feature):
    return{
        'opacity': 0.8, # 선 투명
        'weight': 2, # 선 두께
        'color': 'lightblue', # 색상
        'fillOpacity': 0.2, # 채우기 투명도
        'dashArray': '5, 5' # 선 종류
    }

# %%
## 스타벅스 평균 매장 수 계산. 구별로 평균을 냈을 때 24.56이 나왔다
sb_mean = df_seoul_total['매장수'].mean()

# %%
## CartoDB.dark_matter는 경계표시는 눈에 잘보이게
seoul_map = folium.Map(location=seoul_center, zoom_start=11, tiles='CartoDB.dark_matter')

# 지역 경계 표시
folium.GeoJson(geojson, style_function=set_style).add_to(seoul_map)

## 서울구별 정보를 지도출력
for idx in df_seoul_total.index:
    lat = df_seoul_total.loc[idx, '위도']
    lng = df_seoul_total.loc[idx, '경도']
    count = df_seoul_total.loc[idx, '매장수']
    gu_name = df_seoul_total.loc[idx, '구']

    fill_color = ''
    if count > sb_mean: fill_color = 'darkred'
    else: fill_color = 'blue'

    popup_text = f'<strong style="font-size:15px;color:blue">{df_seoul_total.loc[idx, "구"]}</strong><br/>{count}개'
    popup = folium.Popup(popup_text, max_width=300)

    ## 구마다 서클마커 표시
    folium.CircleMarker(location=[lat, lng], popup=popup,
                        color='yellow', fill_color=fill_color, fill_opacity=0.7,
                        weight=2, radius=count/2).add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed3a5e8730d126c809a9902f4c861c7a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed3a5e8730d126c809a9902f4c861c7a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed3a5e8730d126c809a9902f4c861c7a = L.map(
#                 &quot;map_ed3a5e8730d126c809a9902f4c861c7a&quot;,
#                 {
#                     center: [37.5508, 126.989857],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f36620b173b52720180cf769c5de1cca = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f36620b173b52720180cf769c5de1cca.addTo(map_ed3a5e8730d126c809a9902f4c861c7a);
#
#
#         function geo_json_c7446637eef843227deb03636eaea4a5_styler(feature) {
#             switch(feature.properties.code) {
#                 default:
#                     return {&quot;color&quot;: &quot;lightblue&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_c7446637eef843227deb03636eaea4a5_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c7446637eef843227deb03636eaea4a5 = L.geoJson(null, {
#                 onEachFeature: geo_json_c7446637eef843227deb03636eaea4a5_onEachFeature,
#
#                 style: geo_json_c7446637eef843227deb03636eaea4a5_styler,
#         });
#
#         function geo_json_c7446637eef843227deb03636eaea4a5_add (data) {
#             geo_json_c7446637eef843227deb03636eaea4a5
#                 .addData(data);
#         }
#             geo_json_c7446637eef843227deb03636eaea4a5_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.524841220167055], [127.10484130265957, 37.53120327509912], [127.1116764203608, 37.540669955324965], [127.12061313033807, 37.538129867839416], [127.12532464331997, 37.53572787912298], [127.12251496040881, 37.52751810228347], [127.12123165719615, 37.52528270089], [127.14532023498624, 37.51464060108829], [127.14672806823502, 37.51415680680291], [127.14670263739373, 37.512786602955565], [127.14462782318448, 37.511529542030715], [127.14323992504048, 37.50951977457089], [127.1420864475393, 37.50578973782813], [127.14324986168657, 37.502649431479774], [127.1473517108062, 37.50069754405746], [127.1498011

# %% [markdown]
# - 실행결과
#
# <img src= "https://raw.githubusercontent.com/LEUNSU/iot-bigdata-2024/main/images/bda002.png" width="730">

# %% [markdown]
# - 맷플롯립, 포리움 사용가능한 칼라맵
#     - ['Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
#                       'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
#                       'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']
#     - ['viridis', 'plasma', 'inferno', 'magma', 'cividis']

# %%
## 구별 인구수와 스타벅스 매장간 관계 지도 시각화(위의 지도 내용 그대로 사용)
seoul_map = folium.Map(location=seoul_center, zoom_start=11, tiles='CartoDB.dark_matter')

# 지역경계선 표시
folium.GeoJson(geojson, style_function=set_style).add_to(seoul_map)
# 지역경계별 색상
folium.Choropleth(geo_data=geojson, data=df_seoul_total, columns=['구', '매장수'], legend_name='구별 스타벅스 매장수',
                fill_color='YlGn', fill_opacity=0.6, line_opacity=0.5, key_on='properties.name').add_to(seoul_map)

## 서울구별 정보를 지도 출력
for idx in df_seoul_total.index:
    lat = df_seoul_total.loc[idx, '위도']
    lng = df_seoul_total.loc[idx, '경도']
    count = df_seoul_total.loc[idx, '매장수']
    gu_name = df_seoul_total.loc[idx, '구']
    # DivIcon 클래스로 객체변수 생성
    icon = DivIcon(icon_size=(150, 60), icon_anchor=(75, 25),
                    html=f'''
                    <div style="font-size: 8pt; font-weight: bold; color:blue; text-align: center;">
                        {gu_name} / {count}개
                    </div>
                        ''')

    ## 구마다 서클마커 표시
    folium.Marker(location=[lat, lng], icon=icon).add_to(seoul_map)

seoul_map
## 구마다 색상을 표시. 매장 수가 많으면 진하게 표시
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fe1dc46be9ba763298c627d0b3127a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fe1dc46be9ba763298c627d0b3127a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9fe1dc46be9ba763298c627d0b3127a3 = L.map(
#                 &quot;map_9fe1dc46be9ba763298c627d0b3127a3&quot;,
#                 {
#                     center: [37.5508, 126.989857],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d4fdec4a24f5990e8324145c540ed7da = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d4fdec4a24f5990e8324145c540ed7da.addTo(map_9fe1dc46be9ba763298c627d0b3127a3);
#
#
#         function geo_json_bfff9150a659933bf354ef1b8c57519c_styler(feature) {
#             switch(feature.properties.code) {
#                 default:
#                     return {&quot;color&quot;: &quot;lightblue&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_bfff9150a659933bf354ef1b8c57519c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_bfff9150a659933bf354ef1b8c57519c = L.geoJson(null, {
#                 onEachFeature: geo_json_bfff9150a659933bf354ef1b8c57519c_onEachFeature,
#
#                 style: geo_json_bfff9150a659933bf354ef1b8c57519c_styler,
#         });
#
#         function geo_json_bfff9150a659933bf354ef1b8c57519c_add (data) {
#             geo_json_bfff9150a659933bf354ef1b8c57519c
#                 .addData(data);
#         }
#             geo_json_bfff9150a659933bf354ef1b8c57519c_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.524841220167055], [127.10484130265957, 37.53120327509912], [127.1116764203608, 37.540669955324965], [127.12061313033807, 37.538129867839416], [127.12532464331997, 37.53572787912298], [127.12251496040881, 37.52751810228347], [127.12123165719615, 37.52528270089], [127.14532023498624, 37.51464060108829], [127.14672806823502, 37.51415680680291], [127.14670263739373, 37.512786602955565], [127.14462782318448, 37.511529542030715], [127.14323992504048, 37.50951977457089], [127.1420864475393, 37.505

# %% [markdown]
# - 실행결과
#
# <img src= "https://raw.githubusercontent.com/LEUNSU/iot-bigdata-2024/main/images/bda003.png" width="730">

# %%
## 구별 인구수와 지도 시각화
seoul_map = folium.Map(location=seoul_center, zoom_start=11, tiles='CartoDB.dark_matter')

# 지역경계선 표시
folium.GeoJson(geojson, style_function=set_style).add_to(seoul_map)
# 지역경계별 색상
folium.Choropleth(geo_data=geojson, data=df_seoul_total, columns=['구', '인구수'], legend_name='구별 인구수',
                fill_color='YlOrBr', fill_opacity=0.6, line_opacity=0.5, key_on='properties.name').add_to(seoul_map)

## 서울구별 정보를 지도 출력
for idx in df_seoul_total.index:
    lat = df_seoul_total.loc[idx, '위도']
    lng = df_seoul_total.loc[idx, '경도']
    count = df_seoul_total.loc[idx, '매장수']
    gu_name = df_seoul_total.loc[idx, '구']
    # DivIcon 클래스로 객체변수 생성
    icon = DivIcon(icon_size=(150, 60), icon_anchor=(75, 25),
                    html=f'''
                    <div style="font-size: 8pt; font-weight: bold; color:blue; text-align: center;">
                        {gu_name} / {count}개
                    </div>
                        ''')

    ## 구마다 서클마커 표시
    folium.Marker(location=[lat, lng], icon=icon).add_to(seoul_map)

seoul_map
## 구마다 색상을 표시. 매장수가 많으면 진하게 표시
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_87235ca3954f10c8f522c40c0a6666c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_87235ca3954f10c8f522c40c0a6666c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_87235ca3954f10c8f522c40c0a6666c7 = L.map(
#                 &quot;map_87235ca3954f10c8f522c40c0a6666c7&quot;,
#                 {
#                     center: [37.5508, 126.989857],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9ee438c3a02380ae6ae3c6406e93c6c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d9ee438c3a02380ae6ae3c6406e93c6c.addTo(map_87235ca3954f10c8f522c40c0a6666c7);
#
#
#         function geo_json_3b078bb9b2813227f12252102c396f8b_styler(feature) {
#             switch(feature.properties.code) {
#                 default:
#                     return {&quot;color&quot;: &quot;lightblue&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_3b078bb9b2813227f12252102c396f8b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_3b078bb9b2813227f12252102c396f8b = L.geoJson(null, {
#                 onEachFeature: geo_json_3b078bb9b2813227f12252102c396f8b_onEachFeature,
#
#                 style: geo_json_3b078bb9b2813227f12252102c396f8b_styler,
#         });
#
#         function geo_json_3b078bb9b2813227f12252102c396f8b_add (data) {
#             geo_json_3b078bb9b2813227f12252102c396f8b
#                 .addData(data);
#         }
#             geo_json_3b078bb9b2813227f12252102c396f8b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.524841220167055], [127.10484130265957, 37.53120327509912], [127.1116764203608, 37.540669955324965], [127.12061313033807, 37.538129867839416], [127.12532464331997, 37.53572787912298], [127.12251496040881, 37.52751810228347], [127.12123165719615, 37.52528270089], [127.14532023498624, 37.51464060108829], [127.14672806823502, 37.51415680680291], [127.14670263739373, 37.512786602955565], [127.14462782318448, 37.511529542030715], [127.14323992504048, 37.50951977457089], [127.1420864475393, 37.505

# %%
## 구별 사업체종사자수 지도 시각화
seoul_map = folium.Map(location=seoul_center, zoom_start=11, tiles='CartoDB.dark_matter')

# 지역경계선 표시
folium.GeoJson(geojson, style_function=set_style).add_to(seoul_map)
# 지역경계별 색상
folium.Choropleth(geo_data=geojson, data=df_seoul_total, columns=['구', '사업체종사자수'], legend_name='구별 사업체종사자수',
                fill_color='PuRd', fill_opacity=0.6, line_opacity=0.5, key_on='properties.name').add_to(seoul_map)

## 서울구별 정보를 지도 출력
for idx in df_seoul_total.index:
    lat = df_seoul_total.loc[idx, '위도']
    lng = df_seoul_total.loc[idx, '경도']
    count = df_seoul_total.loc[idx, '사업체종사자수']
    gu_name = df_seoul_total.loc[idx, '구']
    # DivIcon 클래스로 객체변수 생성
    icon = DivIcon(icon_size=(150, 60), icon_anchor=(75, 25),
                    html=f'''
                    <div style="font-size: 8pt; font-weight: bold; color:blue; text-align: center;">
                        {gu_name} / {count}개
                    </div>
                        ''')

    ## 구마다 서클마커 표시
    folium.Marker(location=[lat, lng], icon=icon).add_to(seoul_map)

seoul_map
## 구마다 색상을 표시. 매장수가 많으면 진하게 표시
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_771e5aa8899480bab4a874929718d315 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_771e5aa8899480bab4a874929718d315&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_771e5aa8899480bab4a874929718d315 = L.map(
#                 &quot;map_771e5aa8899480bab4a874929718d315&quot;,
#                 {
#                     center: [37.5508, 126.989857],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb8cda7fae73411e8b21b8b09641962e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fb8cda7fae73411e8b21b8b09641962e.addTo(map_771e5aa8899480bab4a874929718d315);
#
#
#         function geo_json_1a8d7cb0a55ad3141fd2942e21b2f3e8_styler(feature) {
#             switch(feature.properties.code) {
#                 default:
#                     return {&quot;color&quot;: &quot;lightblue&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_1a8d7cb0a55ad3141fd2942e21b2f3e8_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1a8d7cb0a55ad3141fd2942e21b2f3e8 = L.geoJson(null, {
#                 onEachFeature: geo_json_1a8d7cb0a55ad3141fd2942e21b2f3e8_onEachFeature,
#
#                 style: geo_json_1a8d7cb0a55ad3141fd2942e21b2f3e8_styler,
#         });
#
#         function geo_json_1a8d7cb0a55ad3141fd2942e21b2f3e8_add (data) {
#             geo_json_1a8d7cb0a55ad3141fd2942e21b2f3e8
#                 .addData(data);
#         }
#             geo_json_1a8d7cb0a55ad3141fd2942e21b2f3e8_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.524841220167055], [127.10484130265957, 37.53120327509912], [127.1116764203608, 37.540669955324965], [127.12061313033807, 37.538129867839416], [127.12532464331997, 37.53572787912298], [127.12251496040881, 37.52751810228347], [127.12123165719615, 37.52528270089], [127.14532023498624, 37.51464060108829], [127.14672806823502, 37.51415680680291], [127.14670263739373, 37.512786602955565], [127.14462782318448, 37.511529542030715], [127.14323992504048, 37.50951977457089], [127.1420864475393, 37.505

# %% [markdown]
# #### 결론
# - 사업체종사자수가 많은 곳에 스타벅스 매장이 많이 생긴다!
